# %% [markdown]
# <a href="https://colab.research.google.com/github/jaykay4403/Bayesian-ML/blob/main/Football_Project_jk_v_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pandas_profiling
from pandas_profiling import ProfileReport 

import matplotlib.pyplot as plt

import warnings

from collections import OrderedDict
from time import time

import arviz as az
import pymc3 as pm
import seaborn as sns
import theano as thno
import theano.tensor as T

from scipy import integrate
from scipy.optimize import fmin_powell

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# pandas profiling
#!pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# Fix for Pandas profiling error
# See: https://www.datasciencelearner.com/importerror-cannot-import-name-soft-unicode-from-markupsafe-solved/

#!pip install --user --upgrade aws-sam-cli

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pbp_2020 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/2020 PFF Data.csv", index_col=0)

# %%
# Full_pbp = pd.concat([pbp_2016, pbp_2017, pbp_2018, pbp_2019, pbp_2020, pbp_2021])

# %%
# Full_pbp.columns

# %%
Run_Pass_Columns = ['down','distance','field_position','garbage_time','run_pass']

# %%
Run_Pass = pbp_2020[Run_Pass_Columns]
Run_Pass = Run_Pass[~Run_Pass.run_pass.isnull()]
Run_Pass = Run_Pass[Run_Pass['garbage_time'] == 0]
Run_Pass.head(5)
# Out:
#              down  distance  field_position  garbage_time run_pass
# plays.63371     1        10             -25             0        R
# plays.63372     1        10             -19             0        R
# plays.63268     2         4             -25             0        P
# plays.63269     1        10              48             0        P
# plays.63877     2        10              48             0        P

# %%
def f(row):
    if row['field_position'] < 0:
        val = (100 + row['field_position'])
    else:
        val = row['field_position']
    return val

# %%
Run_Pass.head(5)
# Out:
#              down  distance  field_position  garbage_time run_pass
# plays.63371     1        10             -25             0        R
# plays.63372     1        10             -19             0        R
# plays.63268     2         4             -25             0        P
# plays.63269     1        10              48             0        P
# plays.63877     2        10              48             0        P

# %%
Run_Pass['NewFPos'] = Run_Pass.apply(f, axis=1)

# %%
run_pass = 1 * (Run_Pass['run_pass'] == "P")

# %%
Run_Pass["run_pass"] = run_pass

# %%
Run_Pass.head(5)
# Out:
#              down  distance  field_position  garbage_time  run_pass  NewFPos
# plays.63371     1        10             -25             0         0       75
# plays.63372     1        10             -19             0         0       81
# plays.63268     2         4             -25             0         1       75
# plays.63269     1        10              48             0         1       48
# plays.63877     2        10              48             0         1       48

# %%
warnings.filterwarnings("ignore")

# %%
# %matplotlib inline
RANDOM_SEED = 8927
np.random.seed(RANDOM_SEED)

# %%
def run_models(df, upper_order=5):
    """
    Convenience function:
    Fit a range of pymc3 models of increasing polynomial complexity.
    Suggest limit to max order 5 since calculation time is exponential.
    """

    models, traces = OrderedDict(), OrderedDict()

    for k in range(1, upper_order + 1):

        nm = f"k{k}"
        fml = create_poly_modelspec(k)

        with pm.Model() as models[nm]:

            print(f"\nRunning: {nm}")
            pm.glm.GLM.from_formula(fml, df, family=pm.glm.families.Binomial())

            traces[nm] = pm.sample(1000, tune=1000, init="adapt_diag", return_inferencedata=True)

    return models, traces


def plot_traces(traces, model, retain=0):
    """
    Convenience function:
    Plot traces with overlaid means and values
    """
    with model:
        ax = az.plot_trace(
            traces[-retain:],
            lines=tuple([(k, {}, v["mean"]) for k, v in az.summary(traces[-retain:]).iterrows()]),
        )

        for i, mn in enumerate(az.summary(traces[-retain:])["mean"]):
            ax[i, 0].annotate(
                f"{mn:.2f}",
                xy=(mn, 0),
                xycoords="data",
                xytext=(5, 10),
                textcoords="offset points",
                rotation=90,
                va="bottom",
                fontsize="large",
                color="#AA0022",
            )


def create_poly_modelspec(k=1):
    """
    Convenience function:
    Create a polynomial modelspec string for patsy
    """
    return (
        "run_pass ~ down + distance " + " ".join([f"+ np.power(age,{j})" for j in range(2, k + 1)])
    ).strip()

# %%
with pm.Model() as logistic_model:


  
    priors = {'down': pm.Beta.dist(alpha=1.0, beta=1.0),
             'distance': pm.Normal.dist(mu=0.0, sigma=1.0)}
             
    out = pm.glm.GLM.from_formula("run_pass ~ down + distance", 
                                  Run_Pass, family=pm.glm.families.Binomial()
    )
    
    trace = pm.sample(1000, tune=1000, init="adapt_diag")
# Out:
# The glm module is deprecated and will be removed in version 4.0
# We recommend to instead use Bambi https://bambinos.github.io/bambi/
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [distance, down, Intercept]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 09:14<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 554 seconds.

# %%
with logistic_model:
    prior_checks = pm.sample_prior_predictive(samples=100, random_seed=14)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-618373c03f8f> in <module>()
#       1 with logistic_model:
# ----> 2     prior_checks = pm.sample_prior_predictive(samples=100, random_seed=14)
#
# /usr/local/lib/python3.7/dist-packages/pymc3/sampling.py in sample_prior_predictive(samples, model, var_names, random_seed)
#    1942     names = get_default_varnames(vars_, include_transformed=False)
#    1943     # draw_values fails with auto-transformed variables. transform them later!
# -> 1944     values = draw_values([model[name] for name in names], size=samples)
#    1945
#    1946     data = {k: v for k, v in zip(names, values)}
#
# /usr/local/lib/python3.7/dist-packages/pymc3/distributions/distribution.py in draw_values(params, point, size)
#     789                     # This may fail for autotransformed RVs, which don't
#     790                     # have the random method
# --> 791                     value = _draw_value(next_, point=point, givens=temp_givens, size=size)
#     792                     givens[next_.name] = (next_, value)
#     793                     drawn[(next_, size)] = value
#
# /usr/local/lib/python3.7/dist-packages/pymc3/distributions/distribution.py in _draw_value(param, point, givens, size)
#     953             return point[param.name]
#     954         elif hasattr(param, "random") and param.random is not None:
# --> 955             return param.random(point=point, size=size)
#     956         elif (
#     957             hasattr(param, "distribution")
#
# /usr/local/lib/python3.7/dist-packages/pymc3/model.py in __call__(self, *args, **kwargs)
#     103
#     104     def __call__(self, *args, **kwargs):
# --> 105         return getattr(self.obj, self.method_name)(*args, **kwargs)
#     106
#     107
#
# /usr/local/lib/python3.7/dist-packages/pymc3/distributions/continuous.py in random(self, point, size)
#     322         ValueError
#     323         """
# --> 324         raise ValueError("Cannot sample from Flat distribution")
#     325
#     326     def logp(self, value):
#
# ValueError: Cannot sample from Flat distribution

# %%
plot_traces(trace, logistic_model)

# %%
plt.figure(figsize=(9, 7))
sns.jointplot(trace["down"], trace["distance"], kind="hex", color="#4CB391")
plt.xlabel("beta_down")
plt.ylabel("beta_distance")
# Out:
# Text(27.125, 0.5, 'beta_distance')

# %%
# forest plot
pm.plots.forestplot(trace, figsize=(12,5))
plt.grid()
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.

# %%
az.plot_posterior(trace)
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fad1d63ba90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fad1a01a390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fad1cac1b10>],
#       dtype=object)

# %%
pm.summary(trace)
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
#             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# Intercept -1.904  0.032  -1.962   -1.843      0.001    0.001     739.0
# down       0.538  0.010   0.519    0.555      0.000    0.000     770.0
# distance   0.125  0.002   0.121    0.130      0.000    0.000     866.0
#
#            ess_tail  r_hat
# Intercept     724.0    1.0
# down          799.0    1.0
# distance      901.0    1.0

# %%
with logistic_model:
    ppc = pm.sample_posterior_predictive(trace, samples=500)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='500' class='' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [500/500 00:00<00:00]
#     </div>

# %%
with logistic_model:
    global ps
    ps = pm.sample_posterior_predictive(trace, samples=1000)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 00:00<00:00]
#     </div>

# %%
# Update data reference.
#pm.set_data({"data": X_test}, model=logistic_model)
# Generate posterior samples.

ppc_test = pm.sample_posterior_predictive(trace, model=logistic_model, samples=1000)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 00:13<00:00]
#     </div>

# %%
sample_post_pred_pymc = ppc_test['run_pass']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-988077f797a6> in <module>()
# ----> 1 sample_post_pred_pymc = ppc_test['run_pass']
#
# KeyError: 'run_pass'

# %%
# Compute the point prediction by taking the mean
# and defining the category via a threshold.
p_test_pred = ppc_test['run_pass'].mean(axis=0)
y_test_pred = (p_test_pred >= 0.5).astype("int")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-126-e9e0e387dd4b> in <module>()
#       1 # Compute the point prediction by taking the mean
#       2 # and defining the category via a threshold.
# ----> 3 p_test_pred = ppc_test['run_pass'].mean(axis=0)
#       4 y_test_pred = (p_test_pred >= 0.5).astype("int")
#
# KeyError: 'run_pass'

# %%
burn_in = 4000
pred_by_mean = (trace_lite['y_test'][burn_in:]).mean(axis=0) > 0.5
# accuracy
(pred_by_mean == y_test).mean()
#
#TODO: Why is this result so poor??
# This should give approximately the same result as computation
# with the parameter trace (as below)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-60d41e49a7f3> in <module>()
#       1 burn_in = 4000
# ----> 2 pred_by_mean = (trace_lite['y_test'][burn_in:]).mean(axis=0) > 0.5
#       3 # accuracy
#       4 (pred_by_mean == y_test).mean()
#       5 #
#
# /usr/local/lib/python3.7/dist-packages/pymc3/backends/base.py in __getitem__(self, idx)
#     344         if var in self.stat_names:
#     345             return self.get_sampler_stats(var, burn=burn, thin=thin)
# --> 346         raise KeyError("Unknown variable %s" % var)
#     347
#     348     _attrs = {"_straces", "varnames", "chains", "stat_names", "supports_sampler_stats", "_report"}
#
# KeyError: 'Unknown variable y_test'

# %%
#sns.distplot(trace.get_sampler_stats('logistic_model'))
trace.stat_names
trace.varnames
# Out:
# ['Intercept', 'down', 'distance']

# %%
import sklearn.linear_model
clf = sklearn.linear_model.LogisticRegression(C=1.0)
clf.fit(X_train, y_train)
prediction_freq = clf.predict(X_test[:,1:])
(prediction_freq == y_test).mean()
#http://christianherta.de/lehre/dataScience/machineLearning/mcmc/logisticRegressionPymc3.slides.php
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-158-96920416ef92> in <module>()
#       2 clf = sklearn.linear_model.LogisticRegression(C=1.0)
#       3 clf.fit(X_train, y_train)
# ----> 4 prediction_freq = clf.predict(X_test[:,1:])
#       5 (prediction_freq == y_test).mean()
#       6 #http://christianherta.de/lehre/dataScience/machineLearning/mcmc/logisticRegressionPymc3.slides.php
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), slice(1, None, None))' is an invalid key

# %%
X_test#[1:,1:]
# Out:
#              down  distance
# plays.58337     1        10
# plays.33212     3         8
# plays.74790     2        13
# plays.79126     2         7
# plays.67854     3         7
# ...           ...       ...
# plays.92114     1        10
# plays.13949     2         3
# plays.84135     2        10
# plays.23516     2         6
# plays.61983     2         4
#
# [39601 rows x 2 columns]

# %%
trace_lite
# Out:
# <MultiTrace: 2 chains, 1000 iterations, 3 variables>

# %%
with logistic_model:
    ppc = pm.sample_posterior_predictive(trace, random_seed=14)
az.plot_ppc(az.from_pymc3(posterior_predictive=ppc, model=logistic_model));
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:00<00:00]
#     </div>
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-92-3fd476cf05b4> in <module>()
#       1 with logistic_model:
#       2     ppc = pm.sample_posterior_predictive(trace, random_seed=14)
# ----> 3 az.plot_ppc(az.from_pymc3(posterior_predictive=ppc, model=logistic_model));
#
# /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3_3x.py in from_pymc3(trace, prior, posterior_predictive, log_likelihood, coords, dims, model, save_warmup, density_dist_obs)
#     587         model=model,
#     588         save_warmup=save_warmup,
# --> 589         density_dist_obs=density_dist_obs,
#     590     ).to_inference_data()
#     591
#
# /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3_3x.py in __init__(self, trace, prior, posterior_predictive, log_likelihood, predictions, coords, dims, model, save_warmup, density_dist_obs)
#     166                 )
#     167
# --> 168             aelem = arbitrary_element(get_from)
#     169             self.ndraws = aelem.shape[0]
#     170
#
# /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3_3x.py in arbitrary_element(dct)
#     146
#     147         def arbitrary_element(dct: Dict[Any, np.ndarray]) -> np.ndarray:
# --> 148             return next(iter(dct.values()))
#     149
#     150         if trace is None:
#
# StopIteration:

# %%
def lm_full(trace, down, distance):
    shape = np.broadcast(down, distance).shape
    x_norm = np.asarray([np.broadcast_to(x, shape) for x in [down, distance]])
    return 1 / (
        1
        + np.exp(
            -(
                trace["Intercept"]
                + trace["down"] * x_norm[0]
                + trace["distance"] * x_norm[1]
            )
        )
    )


lm = lambda x, samples: lm_full(samples, 1, x)

lm2 = lambda x, samples: lm_full(samples, 2, x)

lm3 = lambda x, samples: lm_full(samples, 3, x)

# %%
# Plot the posterior predictive distributions of P(income > $50K) vs. age
pm.plot_posterior_predictive_glm(
    trace, eval=np.linspace(1, 20, 1000), lm=lm, samples=100, color="blue", alpha=0.15
)
pm.plot_posterior_predictive_glm(
    trace,
    eval=np.linspace(1, 20, 1000),
    lm=lm2,
    samples=100,
    color="green",
    alpha=0.15,
)
pm.plot_posterior_predictive_glm(
    trace, eval=np.linspace(1, 20, 1000), lm=lm3, samples=100, color="red", alpha=0.15
)

import matplotlib.lines as mlines

blue_line = mlines.Line2D(["lm"], [], color="b", label="1st down")
green_line = mlines.Line2D(["lm2"], [], color="g", label="2nd down")
red_line = mlines.Line2D(["lm3"], [], color="r", label="3rd down")
plt.legend(handles=[blue_line, green_line, red_line], loc="lower right")
plt.show()

# %%
plt.figure(figsize=(7, 5))
plt.plot(Run_Pass['distance'], Run_Pass['down'], "x", label="data")
pm.plot_posterior_predictive_glm(trace_lite, samples=100, label="posterior predictive regression lines")
#plt.plot(x, true_regression_line, label="true regression line", lw=3.0, c="y")

plt.legend(loc=0);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-1b174d5d8080> in <module>()
#       1 plt.figure(figsize=(7, 5))
#       2 plt.plot(Run_Pass['distance'], Run_Pass['down'], "x", label="data")
# ----> 3 pm.plot_posterior_predictive_glm(trace_lite, samples=100, label="posterior predictive regression lines")
#       4 #plt.plot(x, true_regression_line, label="true regression line", lw=3.0, c="y")
#       5
#
# /usr/local/lib/python3.7/dist-packages/pymc3/plots/posteriorplot.py in plot_posterior_predictive_glm(trace, eval, lm, samples, **kwargs)
#      80     for rand_loc in np.random.randint(0, len(trace), samples):
#      81         rand_sample = trace[rand_loc]
# ---> 82         plt.plot(eval, lm(eval, rand_sample), **kwargs)
#      83         # Make sure to not plot label multiple times
#      84         kwargs.pop("label", None)
#
# /usr/local/lib/python3.7/dist-packages/pymc3/plots/posteriorplot.py in <lambda>(x, sample)
#      64
#      65     if lm is None:
# ---> 66         lm = lambda x, sample: sample["Intercept"] + sample["x"] * x
#      67
#      68     if eval is None:
#
# KeyError: 'x'

# %%
import matplotlib as mpl
#figsize(12.5, 4.5)
#plt.cmap = mpl.colors.ListedColormap(colors)
plt.imshow(trace["logistic_model"][::400, np.argsort(data)],
       cmap=plt.cmap, aspect=.4, alpha=.9)
plt.xticks(np.arange(0, data.shape[0], 40),
       ["%.2f" % s for s in np.sort(data)[::40]])
plt.ylabel("posterior sample")
plt.xlabel("value of $i$th data point")
plt.title("Posterior labels of data points");
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-33c717ba2182> in <module>()
#       2 #figsize(12.5, 4.5)
#       3 #plt.cmap = mpl.colors.ListedColormap(colors)
# ----> 4 plt.imshow(trace["logistic_model"][::400, np.argsort(data)],
#       5        cmap=plt.cmap, aspect=.4, alpha=.9)
#       6 plt.xticks(np.arange(0, data.shape[0], 40),
#
# /usr/local/lib/python3.7/dist-packages/pymc3/backends/base.py in __getitem__(self, idx)
#     344         if var in self.stat_names:
#     345             return self.get_sampler_stats(var, burn=burn, thin=thin)
# --> 346         raise KeyError("Unknown variable %s" % var)
#     347
#     348     _attrs = {"_straces", "varnames", "chains", "stat_names", "supports_sampler_stats", "_report"}
#
# KeyError: 'Unknown variable logistic_model'

# %%
cmap = mpl.colors.LinearSegmentedColormap.from_list("BMH", colors)
assign_trace = trace["assignment"]
plt.scatter(data, 1 - assign_trace.mean(axis=0), cmap=cmap,
        c=assign_trace.mean(axis=0), s=50)
plt.ylim(-0.05, 1.05)
plt.xlim(35, 300)
plt.title("Probability of data point belonging to cluster 0")
plt.ylabel("probability")
plt.xlabel("value of data point");

# %%
Run_Pass_lite = Run_Pass.drop(Run_Pass.index[0:70000], inplace=False)
Run_Pass_lite
# Out:
#              down  distance  field_position  garbage_time  run_pass  NewFPos
# plays.33117     1        10              24             0         1       24
# plays.32040     2         8              22             0         0       22
# plays.32690     3         6              20             0         1       20
# plays.33627     1        10             -20             0         1       80
# plays.33981     2         3             -27             0         0       73
# ...           ...       ...             ...           ...       ...      ...
# plays.10182     1        10              50             0         0       50
# plays.10265     2         7              47             0         1       47
# plays.9523      3         7              47             0         0       47
# plays.10204     4         7              47             0         1       47
# plays.9312      1        10             -26             0         0       74
#
# [9201 rows x 6 columns]

# %%
print(f"labels = {labels}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-5e730c21faf5> in <module>()
# ----> 1 print(f"labels = {labels}")
#
# NameError: name 'labels' is not defined

# %%
with pm.Model() as logistic_model_lite:

    data = pm.Data("data", X_train)

    family = pm.glm.families.Binomial()
    
    priors = {"Intercept": pm.Normal.dist(mu=0, sd=10),
              'down': pm.Beta.dist(alpha=1.0, beta=1.0),
              'distance': pm.Normal.dist(mu=0.0, sigma=1.0),}

    pm.glm.GLM.from_formula(formula = "run_pass ~ down + distance",
                            y=y_train,
            x=data,
            family=family,
            intercept=False,
            priors=priors
            )

    trace_lite = pm.sample(1000, tune=1000, init="adapt_diag")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-142-c576a84a6bbf> in <module>()
#      14             family=family,
#      15             intercept=False,
# ---> 16             priors=priors
#      17             )
#      18
#
# TypeError: from_formula() got an unexpected keyword argument 'y'

# %%
with pm.Model() as logistic_model_lite:
    
    priors = {"Intercept": pm.Normal.dist(mu=0, sd=10),
              'down': pm.Beta.dist(alpha=1.0, beta=1.0),
              'distance': pm.Normal.dist(mu=0.0, sigma=1.0)}

    out = pm.glm.GLM.from_formula(
        
        "run_pass ~ down + distance", Run_Pass_lite, priors = priors,
        family=pm.glm.families.Binomial()
    )
    trace_lite = pm.sample(1000, tune=1000, init="adapt_diag")
# Out:
# The glm module is deprecated and will be removed in version 4.0
# We recommend to instead use Bambi https://bambinos.github.io/bambi/
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [distance, down, Intercept]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 01:31<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 91 seconds.
# The number of effective samples is smaller than 25% for some parameters.

# %%
with logistic_model_lite:
    ppc = pm.sample_prior_predictive(trace_lite)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-23dc577cd61d> in <module>()
#       1 with logistic_model_lite:
# ----> 2   ppc = pm.sample_prior_predictive(trace_lite, model=logistic_model_lite)
#
# /usr/local/lib/python3.7/dist-packages/pymc3/sampling.py in sample_prior_predictive(samples, model, var_names, random_seed)
#    1942     names = get_default_varnames(vars_, include_transformed=False)
#    1943     # draw_values fails with auto-transformed variables. transform them later!
# -> 1944     values = draw_values([model[name] for name in names], size=samples)
#    1945
#    1946     data = {k: v for k, v in zip(names, values)}
#
# /usr/local/lib/python3.7/dist-packages/pymc3/distributions/distribution.py in draw_values(params, point, size)
#     722
#     723             name = getattr(p, "name", None)
# --> 724             if (p, size) in drawn:
#     725                 # param was drawn in related contexts
#     726                 v = drawn[(p, size)]
#
# TypeError: unhashable type: 'dict'

# %%
# visualize ppc
ax = plt.subplot()
sns.distplot([n.mean() for n in ppc['run_pass']], kde=False, ax=ax)
ax.axvline(data.mean())
ax.set(title='Posterior predictive of the mean', xlabel='mean(x)', ylabel='Frequency');

# %%
with logistic_model_lite:
    pm.set_data({"data": Run_Pass_lite['distance'].values}, model=logistic_model_lite)
    ppc_test = pm.sample_posterior_predictive(trace_lite, model=logistic_model_lite, random_seed=14)
    
# fig, ax = plt.subplots(figsize=(8,8))
# ax.set_xlim([-30, 30])
# az.plot_ppc(az.from_pymc3(posterior_predictive=ppc_test, model=model_t), ax=ax);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pymc3/model.py in __getitem__(self, key)
#    1235             try:
# -> 1236                 return self.named_vars[self.name_for(key)]
#    1237             except KeyError:
#
# KeyError: 'data'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-8390f2f54319> in <module>()
#       1 with logistic_model_lite:
# ----> 2     pm.set_data({"data": Run_Pass_lite['distance'].values}, model=logistic_model_lite)
#       3     ppc_test = pm.sample_posterior_predictive(trace_lite, model=logistic_model_lite, random_seed=14)
#       4
#       5 # fig, ax = plt.subplots(figsize=(8,8))
#
# /usr/local/lib/python3.7/dist-packages/pymc3/model.py in set_data(new_data, model)
#    1469
#    1470     for variable_name, new_value in new_data.items():
# -> 1471         if isinstance(model[variable_name], SharedVariable):
#    1472             if isinstance(new_value, list):
#    1473                 new_value = np.array(new_value)
#
# /usr/local/lib/python3.7/dist-packages/pymc3/model.py in __getitem__(self, key)
#    1236                 return self.named_vars[self.name_for(key)]
#    1237             except KeyError:
# -> 1238                 raise e
#    1239
#    1240     def makefn(self, outs, mode=None, *args, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/pymc3/model.py in __getitem__(self, key)
#    1231     def __getitem__(self, key):
#    1232         try:
# -> 1233             return self.named_vars[key]
#    1234         except KeyError as e:
#    1235             try:
#
# KeyError: 'data'

# %%
plot_traces(trace_lite, logistic_model_lite)

# %%
with logistic_model_lite:
    ppc = pm.sample_posterior_predictive(trace_lite, samples=500)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='500' class='' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [500/500 00:01<00:00]
#     </div>

# %%
import arviz as az
az.plot_ppc(az.from_pymc3(posterior_predictive=ppc, model=logistic_model_lite))

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-d3392218b611> in <module>()
#       1 import arviz as az
# ----> 2 az.plot_ppc(az.from_pymc3(posterior_predictive=ppc, model=logistic_model_lite))
#
# NameError: name 'ppc' is not defined

# %%
pm.plots.traceplot(trace)
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# Got error No model on context stack. trying to find log_likelihood in translation.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2cd5ffef50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2cd5ee4f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2cd5e53350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2cd5f190d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2cd5e11a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2cd5e4c9d0>]],
#       dtype=object)

# %%
## Compare model fit: DIC vs. WAIC
# See: https://pymc3-testing.readthedocs.io/en/rtd-docs/notebooks/GLM-model-selection.html

# Deviance Information Criterion [DIC] - compares the deviance of likelhood
# across the the sample traces of a model run
#pm.stats.dic(model=logistic_model, trace=trace)
#pm.stats.dic(trace)

# Watanabe - Akaike Information Criterion (WAIC) - calculates the
# goodness-of-fit of amodel using numerical techniques
#pm.stats.waic(model=logistic_model, trace=trace)
pm.stats.waic(trace, pointwise=False), pm.stats.waic(trace_lite, pointwise=False)
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# Got error No model on context stack. trying to find log_likelihood in translation.
# (Computed from 2000 by 79201 log-likelihood matrix
#
#            Estimate       SE
#  elpd_waic -52404.27    73.48
#  p_waic        3.40        -, Computed from 2000 by 9201 log-likelihood matrix
#
#            Estimate       SE
#  elpd_waic -6134.34    23.48
#  p_waic        3.66        -)

# %%
sigma_y = y.std(axis=1)
sigma_y
# Out:
# plays.63371   nan
# plays.21228   nan
# plays.21459   nan
# plays.21684   nan
# plays.21229   nan
#                ..
# plays.10182   nan
# plays.10265   nan
# plays.9523    nan
# plays.10204   nan
# plays.9312    nan
# Length: 19202, dtype: float64

# %%
plot_Run_Pass = Run_Pass.drop(['field_position', 'garbage_time', 'NewFPos'], axis=1)
plot_Run_Pass
# Out:
#              down  distance  run_pass
# plays.63371     1        10         0
# plays.63372     1        10         0
# plays.63268     2         4         1
# plays.63269     1        10         1
# plays.63877     2        10         1
# ...           ...       ...       ...
# plays.10182     1        10         0
# plays.10265     2         7         1
# plays.9523      3         7         0
# plays.10204     4         7         1
# plays.9312      1        10         0
#
# [79201 rows x 3 columns]

# %%
plt.figure(figsize = (15,15))

g = sns.FacetGrid(plot_Run_Pass, col="run_pass", col_wrap=2)
g.map_dataframe(
    sns.regplot, x= 'distance', y="down", x_estimator=np.mean)
g.set_axis_labels(
        x_var='distance', y_var='down'
        )

# control x and y limits
#plt.xlim(0, None)
plt.ylim(0, 4)

g.fig.subplots_adjust(top=.95)
#g.fig.suptitle('Run vs. Pass', y=1.0, fontsize=16)

# %%
plt.figure(figsize = (15,15))
g = sns.FacetGrid(plot_Run_Pass, col="run_pass", col_wrap=2)
g.map_dataframe(
    sns.regplot, x= 'down', y="distance", x_estimator=np.mean)
g.set_axis_labels(
        x_var='down', y_var='distance'
        )
    
g.fig.subplots_adjust(top=.95)
#g.fig.suptitle('Run vs. Pass', y=1.0, fontsize=16)

# %%
# setup for long play plot

plot_Run_Pass_long = plot_Run_Pass
plot_Run_Pass_long['long_distance'] = plot_Run_Pass_long['distance'] > 10
plot_Run_Pass_long
# Out:
#              down  distance  run_pass  long_distance
# plays.63371     1        10         0          False
# plays.63372     1        10         0          False
# plays.63268     2         4         1          False
# plays.63269     1        10         1          False
# plays.63877     2        10         1          False
# ...           ...       ...       ...            ...
# plays.10182     1        10         0          False
# plays.10265     2         7         1          False
# plays.9523      3         7         0          False
# plays.10204     4         7         1          False
# plays.9312      1        10         0          False
#
# [79201 rows x 4 columns]

# %%
# different way to do it than above
long_plot_Run_Pass = plot_Run_Pass.loc[plot_Run_Pass.long_distance == True]
long_plot_Run_Pass
# Out:
#              down  distance  run_pass  long_distance
# plays.63376     2        11         1           True
# plays.63894     1        15         1           True
# plays.63011     1        15         1           True
# plays.63870     2        13         1           True
# plays.63366     2        12         0           True
# ...           ...       ...       ...            ...
# plays.9288      2        12         0           True
# plays.9154      3        17         0           True
# plays.10017     2        11         0           True
# plays.10217     2        14         1           True
# plays.9205      3        14         1           True
#
# [8220 rows x 4 columns]

# %%
long_plot_Run_Pass['long_distance'].value_counts()
# Out:
# True    8220
# Name: long_distance, dtype: int64

# %%
plt.figure(figsize = (20,20))
g = sns.FacetGrid(long_plot_Run_Pass, col="run_pass", col_wrap=2)
g.map_dataframe(
    sns.regplot, x= 'down', y="distance", x_estimator=np.mean)
g.set_axis_labels(
        x_var='down', y_var='distance'
        )
    
g.fig.subplots_adjust(top=.95)
#g.fig.suptitle('Run vs. Pass: Long Play', y=1.0, fontsize=16)

# %%
long_plot_Run_Pass
# Out:
#              down  distance  run_pass  long_distance
# plays.63376     2        11         1           True
# plays.63894     1        15         1           True
# plays.63011     1        15         1           True
# plays.63870     2        13         1           True
# plays.63366     2        12         0           True
# ...           ...       ...       ...            ...
# plays.9288      2        12         0           True
# plays.9154      3        17         0           True
# plays.10017     2        11         0           True
# plays.10217     2        14         1           True
# plays.9205      3        14         1           True
#
# [8220 rows x 4 columns]

# %%
ax = sns.regplot(x="down", y="distance", data=long_plot_Run_Pass, 
                 logistic=False, n_boot=500, y_jitter=.03)

# %%
ax = sns.regplot(x="distance", y="down", data=long_plot_Run_Pass, 
                 logistic=False, n_boot=500, y_jitter=.03)

# %%
ax = sns.regplot(x="distance", y="down", data=long_plot_Run_Pass, 
                 logistic=False, n_boot=500, y_jitter=.03, x_bins = 4)

# %%
ax = sns.regplot(x="distance", y="down", data=plot_Run_Pass, 
                 logistic=False, n_boot=500, y_jitter=.03, x_bins = 4)

# %%
ax = sns.pairplot(data=plot_Run_Pass, kind = 'reg')

# %%
ax = sns.pairplot(data=plot_Run_Pass.drop(['long_distance'], axis = 1), kind = 'reg')

# %%
Run_Pass['run_pass']
# Out:
# plays.63371    0
# plays.63372    0
# plays.63268    1
# plays.63269    1
# plays.63877    1
#               ..
# plays.10182    0
# plays.10265    1
# plays.9523     0
# plays.10204    1
# plays.9312     0
# Name: run_pass, Length: 79201, dtype: int64

# %%
markers = {0: "s", 1: "X"}
sns.scatterplot(data=Run_Pass, x="down", y="distance", style="run_pass", markers=markers)

# %%
#markers = {0: "s", 1: "X"}
sns.scatterplot(data=Run_Pass, x="distance", y="down")
#run_pass = 1 * (Run_Pass['run_pass'] == "P")

# %%
plot_Run_Pass.count()
# Out:
# down        79201
# distance    79201
# run_pass    79201
# dtype: int64

# %%
X_simple_lite
# Out:
#              down  distance
# plays.63371     1        10
# plays.21228     3         3
# plays.21459     4         4
# plays.21684     1        10
# plays.21229     2         2
# ...           ...       ...
# plays.10182     1        10
# plays.10265     2         7
# plays.9523      3         7
# plays.10204     4         7
# plays.9312      1        10
#
# [19202 rows x 2 columns]

# %%
## do not run, too big, crashes

# %matplotlib inline
import scipy.stats as stats
from IPython.core.pylabtools import figsize
import numpy as np
figsize(12.5, 4)

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#jet = plt.cm.jet
#fig = plt.figure()
x = X_simple_lite['down']  #plot_Run_Pass['down']
y = y_lite  #plot_Run_Pass['run_pass']
X, Y = np.meshgrid(x, y)

# figsize(12.5, 5)
# fig = plt.figure()
# plt.subplot(121)

exp_x = stats.expon.pdf(x, scale=3)
exp_y = stats.expon.pdf(x, scale=10)
M = np.dot(exp_x[:, None], exp_y[None, :])
CS = plt.contour(X, Y, M)
im = plt.imshow(M, interpolation='none', origin='lower',
                cmap=jet, extent=(0, 5, 0, 5))
#plt.xlabel("prior on $p_1$")
#plt.ylabel("prior on $p_2$")
plt.title("$Exp(3), Exp(10)$ prior landscape")

ax = fig.add_subplot(122, projection='3d')
ax.plot_surface(X, Y, M, cmap=jet)
ax.view_init(azim=390)
plt.title("$Exp(3), Exp(10)$ prior landscape; \nalternate view");

# %%
plt.hist(plot_Run_Pass['distance'], bins=20, color="k", histtype="stepfilled", alpha=0.8)
plt.title("Histogram of the dataset")
plt.ylim([0, None]);
print(plot_Run_Pass[:10], "...")
# Out:
#              down  distance  run_pass  long_distance
# plays.63371     1        10         0          False
# plays.63372     1        10         0          False
# plays.63268     2         4         1          False
# plays.63269     1        10         1          False
# plays.63877     2        10         1          False
# plays.63266     1        10         1          False
# plays.63663     2        10         1          False
# plays.63504     3        10         1          False
# plays.63536     4         7         1          False
# plays.62846     1        10         0          False ...

# %%
plt.hist(plot_Run_Pass['down'], bins=20, color="k", histtype="stepfilled", alpha=0.8)
plt.title("Histogram of the dataset")
plt.ylim([0, None]);
#print(plot_Run_Pass[:10], "...")

# %%
plot_Run_Pass['distance'].value_counts()
# Out:
# 10    38801
# 1      3990
# 5      3937
# 7      3868
# 6      3778
# 8      3681
# 4      3351
# 2      3193
# 9      3096
# 3      2998
# 11     1620
# 15     1290
# 12     1181
# 13      810
# 14      671
# 20      575
# 16      427
# 17      348
# 18      309
# 0       288
# 19      257
# 21      158
# 25      134
# 22      113
# 23       85
# 24       73
# 26       46
# 27       25
# 28       25
# 29       21
# 30       14
# 32        9
# 34        5
# 35        5
# 40        5
# 33        4
# 31        3
# 36        3
# 45        1
# 37        1
# 39        1
# 48        1
# Name: distance, dtype: int64

# %%
plot_Run_Pass['down'].value_counts()
# Out:
# 1    34866
# 2    25698
# 3    16224
# 4     2125
# 0      288
# Name: down, dtype: int64

# %%
Run_Pass.head
# Out:
# <bound method NDFrame.head of              down  distance  field_position  garbage_time  run_pass  NewFPos
# plays.63371     1        10             -25             0         0       75
# plays.63372     1        10             -19             0         0       81
# plays.63268     2         4             -25             0         1       75
# plays.63269     1        10              48             0         1       48
# plays.63877     2        10              48             0         1       48
# ...           ...       ...             ...           ...       ...      ...
# plays.10182     1        10              50             0         0       50
# plays.10265     2         7              47             0         1       47
# plays.9523      3         7              47             0         0       47
# plays.10204     4         7              47             0         1       47
# plays.9312      1        10             -26             0         0       74
#
# [79201 rows x 6 columns]>

# %%
## install lazy classifier - run this every new session

# !pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.9-py2.py3-none-any.whl (12 kB)
# Collecting xgboost==1.1.1
#   Downloading xgboost-1.1.1-py3-none-manylinux2010_x86_64.whl (127.6 MB)
#      |████████████████████████████████| 127.6 MB 20 kB/s
# Collecting PyYAML==5.3.1
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
#      |████████████████████████████████| 269 kB 85.9 MB/s
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (7.1.2)
# Collecting scikit-learn==0.23.1
#   Downloading scikit_learn-0.23.1-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 59.1 MB/s
# Collecting numpy==1.19.1
#   Downloading numpy-1.19.1-cp37-cp37m-manylinux2010_x86_64.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 67.7 MB/s
# Collecting pytest==5.4.3
#   Downloading pytest-5.4.3-py3-none-any.whl (248 kB)
#      |████████████████████████████████| 248 kB 78.1 MB/s
# Collecting scipy==1.5.4
#   Downloading scipy-1.5.4-cp37-cp37m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 1.3 MB/s
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.15.0)
# Collecting pandas==1.0.5
#   Downloading pandas-1.0.5-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 79.8 MB/s
# Collecting tqdm==4.56.0
#   Downloading tqdm-4.56.0-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 843 kB/s
# Collecting lightgbm==2.3.1
#   Downloading lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 64.8 MB/s
# Collecting joblib==1.0.0
#   Downloading joblib-1.0.0-py3-none-any.whl (302 kB)
#      |████████████████████████████████| 302 kB 70.4 MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2022.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2.8.2)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (4.11.3)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (8.12.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.3)
# Collecting pluggy<1.0,>=0.12
#   Downloading pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.4.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (1.11.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.2.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.23.1->lazypredict) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytest==5.4.3->lazypredict) (3.0.8)
# Building wheels for collected packages: PyYAML
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44636 sha256=c00a3f5b2df9b9271ab94c40862fa31630f25676fec1fb408475d66804cd6f06
#   Stored in directory: /root/.cache/pip/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
# Successfully built PyYAML
# Installing collected packages: numpy, scipy, joblib, scikit-learn, pluggy, xgboost, tqdm, PyYAML, pytest, pandas, lightgbm, lazypredict
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.0
#     Uninstalling tqdm-4.64.0:
#       Successfully uninstalled tqdm-4.64.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.23.1 which is incompatible.
# tensorflow 2.8.0 requires numpy>=1.20, but you have numpy 1.19.1 which is incompatible.
# imbalanced-learn 0.8.1 requires scikit-learn>=0.24, but you have scikit-learn 0.23.1 which is incompatible.
# google-colab 1.0.0 requires pandas>=1.1.0; python_version >= "3.0", but you have pandas 1.0.5 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed PyYAML-5.3.1 joblib-1.0.0 lazypredict-0.2.9 lightgbm-2.3.1 numpy-1.19.1 pandas-1.0.5 pluggy-0.13.1 pytest-5.4.3 scikit-learn-0.23.1 scipy-1.5.4 tqdm-4.56.0 xgboost-1.1.1

# %%
# setup & run lazy classifier

### importing lazypredict library
import lazypredict
### importing LazyClassifier for classification problem
from lazypredict.Supervised import LazyClassifier
### importing LazyClassifier for classification problem because here we are solving Classification use case.
from lazypredict.Supervised import LazyClassifier
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# Step 1: set up dataframes
y = Run_Pass[['run_pass']]
X_all = Run_Pass.drop(['run_pass'], axis=1)
X_simple = Run_Pass[['down','distance']]

# %%
# Reduce size of dataframe because of memory constrainst
# Causes colab to crash > 20000+ observations

#y.drop([40000,79200], axis=1, inplace=True)
#y.iloc[40000:]
#y.drop(y.index[20000:79200], inplace=True)
y_lite = y.drop(y.index[1:70000], inplace=False)
y_lite
# Out:
#              run_pass
# plays.63371         0
# plays.33117         1
# plays.32040         0
# plays.32690         1
# plays.33627         1
# ...               ...
# plays.10182         0
# plays.10265         1
# plays.9523          0
# plays.10204         1
# plays.9312          0
#
# [9202 rows x 1 columns]

# %%
#X_simple.drop(X_simple.index[20000:79200], inplace=True)
#X_simple
X_simple_lite = X_simple.drop(X_simple.index[1:70000], inplace=False)
X_simple_lite
# Out:
#              down  distance
# plays.63371     1        10
# plays.33117     1        10
# plays.32040     2         8
# plays.32690     3         6
# plays.33627     1        10
# ...           ...       ...
# plays.10182     1        10
# plays.10265     2         7
# plays.9523      3         7
# plays.10204     4         7
# plays.9312      1        10
#
# [9202 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# Step 2: create train-test split - test = 20% / train = 80%
X_train, X_test, y_train, y_test = train_test_split(X_simple, y, train_size = 0.5, random_state = 14 )

# %%
# create an object of LazyClassifier class
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric = None)

# %%
### fitting data in LazyClassifier
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
#  41%|████▏     | 12/29 [01:19<04:26, 15.65s/it]

# %%
# 
isinstance(y, pd.DataFrame)
# Out:
# True

# %%
y
# Out:
#              run_pass
# plays.63371         0
# plays.63372         0
# plays.63268         1
# plays.63269         1
# plays.63877         1
# ...               ...
# plays.10182         0
# plays.10265         1
# plays.9523          0
# plays.10204         1
# plays.9312          0
#
# [79201 rows x 1 columns]

# %%
from pandas_profiling import ProfileReport
pd.options.display.max_columns = None

# Pandas Profiling
profile = ProfileReport(pbp_2020, title='Pandas Profiling Report',
                        html={'style':{'full_width':True}}, explorative=True)
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile.to_file(output_file="football_summary.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
print(repr(profile.report))
# Out:
# Root
